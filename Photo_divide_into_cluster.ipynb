# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitSingh-Rajjput/Machine-Learning-Selfmade-Guide-/blob/main/Photo_divide_into_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In this assignment students have to compress racoon grey scale image into
# 5 clusters. In the end, visualize both raw and compressed image and look
# for quality difference.**

# %%
import numpy as np
from sklearn.cluster import KMeans
import scipy.misc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f=scipy.misc.face(gray=True)
plt.figure(figsize=(10,3))
plt.imshow(f,cmap=plt.cm.gray)
plt.show()

# %%
# Compressing the gray scale image into 5 clusters
rows=f.shape[0]
cols=f.shape[1]
print(rows)
print(cols)
# Out:
# 768
# 1024

# %%
image=f.reshape(rows*cols,1)
kmeans = KMeans(n_clusters = 5)
kmeans.fit(image)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
clusters = np.asarray(kmeans.cluster_centers_) 
labels = np.asarray(kmeans.labels_)  
labels = labels.reshape(rows,cols)

# %%
plt.imsave('compressed_racoon.png',labels)

# %%
image = plt.imread('compressed_racoon.png')
plt.figure(figsize=(10, 3.6))
plt.imshow(image)
plt.show()
